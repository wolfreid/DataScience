# %%
PATH = r"C:\Users\Roman.Prylypko\Documents\MY WORK\RGC programming\RGC analyst python\RGClib"
import sys
import pathlib
current_path = pathlib.Path().resolve()
sys.path.insert(1,PATH )
import images as img
import pandas as pd
input = r"\\Sho-fs02\hq\Departments\NaturalGas\Диспетчерская УК\ЦДУ\Методика прогнозування\расчет населения ПАТ\Прогнозирование\Рома\PR PowerBI\graphics\Тема"
output =input + "_upd" 
file  = pd.read_json(input+".json",lines=True,encoding = 'utf-8-sig')
# file
page = file.visualStyles.to_numpy()[0]['page']
outspace = page['*']['outspace']
url = outspace[0]['image']['url']
outspace[0]['image']['url']= img.TEXT

# %%
page
# Out:
# {'*': {'background': [{'transparency': 100}],
#   'outspace': [{'image': {'name': 'Wave',
#      'scaling': 'Fit',
#      'url': 'data:image/png;base64,...'}}]}}

# %%
file.to_json(output+".json",orient = 'records',lines=True)
